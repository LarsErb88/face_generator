# %% [markdown]
# # Face Generation
#
# In this project, we define and train a DCGAN on a dataset of faces. The goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
#
# ### Get the Data
#
# We will be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train the adversarial networks.
#
#
# ### Pre-processed Data
#
# Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > You can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since we're going to be generating faces, we won't need the annotations, we'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    transform = transforms.Compose([transforms.Resize(image_size), # resize to image_sizeximage_size
                                    transforms.ToTensor()])
    
    imageDataset = datasets.ImageFolder(data_dir, transform) 
    
    imageLoader = torch.utils.data.DataLoader(dataset=imageDataset, batch_size=batch_size, shuffle=True, num_workers=0)
    
    return imageLoader

# %% [markdown]
# ## Create a DataLoader

# %%
# Define function hyperparameters
batch_size = 30
img_size = 32


# Call the function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Pre-process the image data and scale it to a pixel range of -1 to 1
#
# We need to do a bit of pre-processing; we know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale the training images to a range of -1 to 1.

# %%
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.8353)
# Max:  tensor(0.9373)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# The first task will be to define the discriminator. This is a convolutional classifier without any maxpooling layers. To deal with this complex data, it's suggested we use a deep network with **normalization**.

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size=4, stride=2, padding=1, batch_norm=True):

    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    layers.append(conv_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
     
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
    
        self.conv_dim = conv_dim
        # 3 convolutional layer + fully connected layer with one output
        self.conv1 = conv(3, conv_dim, batch_norm=False)
        self.conv2 = conv(conv_dim, conv_dim*2)
        self.conv3 = conv(conv_dim*2, conv_dim*4)
        self.fc = nn.Linear(conv_dim*4*4*4, 1)
        
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """

        x = F.leaky_relu(self.conv1(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = self.dropout(x)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = self.dropout(x)
        # flatten
        x = x.view(-1, self.conv_dim*4*4*4)
        x = self.fc(x)  
        
        return x

tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                                              kernel_size, stride, padding, bias=False)
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)

        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm=False)
        
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4) # (batch_size, depth, 4, 4)
        
        x = F.relu(self.t_conv1(x))
        x = self.dropout(x)
        x = F.relu(self.t_conv2(x))
        x = self.dropout(x)
        x = self.t_conv3(x)
        # tanh -> values between -1 and 1
        x = F.tanh(x)
        return x

tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help our models converge, we initialize the weights of the convolutional and linear layers in the model.
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """

    from torch.nn import init
    classname = m.__class__.__name__
    if classname.find('Conv') != -1 or classname.find('Linear') != -1:
        init.normal_(m.weight.data, 0.0, 0.02)
    if classname.find('Linear') != -1:
        m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# We define the models' hyperparameters and instantiate the discriminator and generator from the classes defined above.

# %%
def build_network(d_conv_dim, g_conv_dim, z_size):
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# ### Training on GPU
#
# If we can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`.

# %%
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size)*0.9 # real labels ~ 1    
    # train on GPU
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    #train on GPU
    if train_on_gpu:
        labels = labels.cuda()
        
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Optimizers for the Discriminator (D) and Generator (G)

# %%
import torch.optim as optim

lr = 0.0002
beta1=0.2
beta2=0.999

# Optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training

# %%
def train(D, G, n_epochs, print_every=300):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    for epoch in range(n_epochs):

        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            
            # 1. Train the discriminator on real and fake images
            # DISCRIMINATOR
            d_optimizer.zero_grad()
            
            # Train with real images
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # Train with fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
                                    
            # sum d_real_loss and d_fake_loss
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step() 

            # 2. Train the generator with an adversarial loss            
            # GENERATOR
            g_optimizer.zero_grad()

            # Generate fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()

            # Print some loss stats
            if batch_i % print_every == 0:
                losses.append((d_loss.item(), g_loss.item()))
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))

        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %%
# set number of epochs 
n_epochs = 25

# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   25] | d_loss: 1.5938 | g_loss: 0.5311
# Epoch [    1/   25] | d_loss: 0.4375 | g_loss: 3.4301
# Epoch [    1/   25] | d_loss: 0.7105 | g_loss: 2.4380
# Epoch [    1/   25] | d_loss: 0.8224 | g_loss: 1.9624
# Epoch [    1/   25] | d_loss: 1.1350 | g_loss: 3.1099
# Epoch [    1/   25] | d_loss: 1.0459 | g_loss: 1.5825
# Epoch [    1/   25] | d_loss: 1.1444 | g_loss: 0.9627
# Epoch [    1/   25] | d_loss: 1.0692 | g_loss: 1.7075
# Epoch [    1/   25] | d_loss: 0.9256 | g_loss: 1.2990
# Epoch [    1/   25] | d_loss: 0.9613 | g_loss: 1.4635
# Epoch [    2/   25] | d_loss: 0.8452 | g_loss: 1.7787
# Epoch [    2/   25] | d_loss: 1.1231 | g_loss: 1.0152
# Epoch [    2/   25] | d_loss: 1.0564 | g_loss: 1.7579
# Epoch [    2/   25] | d_loss: 1.1204 | g_loss: 0.8225
# Epoch [    2/   25] | d_loss: 0.8357 | g_loss: 1.4059
# Epoch [    2/   25] | d_loss: 0.7682 | g_loss: 1.4531
# Epoch [    2/   25] | d_loss: 0.8589 | g_loss: 1.5518
# Epoch [    2/   25] | d_loss: 0.9546 | g_loss: 2.1733
# Epoch [    2/   25] | d_loss: 0.9417 | g_loss: 1.4676
# Epoch [    2/   25] | d_loss: 0.6854 | g_loss: 1.4302
# Epoch [    3/   25] | d_loss: 0.8562 | g_loss: 1.2996
# Epoch [    3/   25] | d_loss: 0.9336 | g_loss: 2.1508
# Epoch [    3/   25] | d_loss: 0.8480 | g_loss: 2.1678
# Epoch [    3/   25] | d_loss: 0.8732 | g_loss: 1.1978
# Epoch [    3/   25] | d_loss: 0.8604 | g_loss: 1.5208
# Epoch [    3/   25] | d_loss: 0.6837 | g_loss: 2.1992
# Epoch [    3/   25] | d_loss: 0.7403 | g_loss: 2.7934
# Epoch [    3/   25] | d_loss: 0.7291 | g_loss: 1.8033
# Epoch [    3/   25] | d_loss: 0.9543 | g_loss: 1.4748
# Epoch [    3/   25] | d_loss: 1.0103 | g_loss: 1.8957
# Epoch [    4/   25] | d_loss: 0.6970 | g_loss: 1.8121
# Epoch [    4/   25] | d_loss: 0.6660 | g_loss: 1.9786
# Epoch [    4/   25] | d_loss: 0.5317 | g_loss: 2.7426
# Epoch [    4/   25] | d_loss: 0.9376 | g_loss: 1.4078
# Epoch [    4/   25] | d_loss: 0.7142 | g_loss: 1.9867
# Epoch [    4/   25] | d_loss: 1.0999 | g_loss: 1.5535
# Epoch [    4/   25] | d_loss: 0.7273 | g_loss: 2.1525
# Epoch [    4/   25] | d_loss: 0.5357 | g_loss: 2.1927
# Epoch [    4/   25] | d_loss: 0.6341 | g_loss: 2.2744
# Epoch [    4/   25] | d_loss: 1.2011 | g_loss: 1.5106
# Epoch [    5/   25] | d_loss: 0.5114 | g_loss: 2.1802
# Epoch [    5/   25] | d_loss: 1.3778 | g_loss: 1.0501
# Epoch [    5/   25] | d_loss: 1.1564 | g_loss: 0.6519
# Epoch [    5/   25] | d_loss: 0.6330 | g_loss: 2.2147
# Epoch [    5/   25] | d_loss: 0.6811 | g_loss: 2.0451
# Epoch [    5/   25] | d_loss: 0.6350 | g_loss: 1.5850
# Epoch [    5/   25] | d_loss: 0.4869 | g_loss: 3.1123
# Epoch [    5/   25] | d_loss: 0.4891 | g_loss: 3.6717
# Epoch [    5/   25] | d_loss: 1.0066 | g_loss: 1.1501
# Epoch [    5/   25] | d_loss: 0.4428 | g_loss: 2.9821
# Epoch [    6/   25] | d_loss: 0.5187 | g_loss: 2.7253
# Epoch [    6/   25] | d_loss: 0.4547 | g_loss: 3.1755
# Epoch [    6/   25] | d_loss: 0.4895 | g_loss: 2.5923
# Epoch [    6/   25] | d_loss: 0.4344 | g_loss: 3.2779
# Epoch [    6/   25] | d_loss: 0.4694 | g_loss: 2.6309
# Epoch [    6/   25] | d_loss: 1.3420 | g_loss: 1.0211
# Epoch [    6/   25] | d_loss: 0.5057 | g_loss: 2.6131
# Epoch [    6/   25] | d_loss: 0.4435 | g_loss: 3.2964
# Epoch [    6/   25] | d_loss: 1.2902 | g_loss: 1.8665
# Epoch [    6/   25] | d_loss: 0.6274 | g_loss: 2.2464
# Epoch [    7/   25] | d_loss: 0.4888 | g_loss: 2.9403
# Epoch [    7/   25] | d_loss: 0.7350 | g_loss: 1.2330
# Epoch [    7/   25] | d_loss: 0.4596 | g_loss: 3.7758
# Epoch [    7/   25] | d_loss: 0.4504 | g_loss: 3.4033
# Epoch [    7/   25] | d_loss: 0.3981 | g_loss: 4.1739
# Epoch [    7/   25] | d_loss: 0.4641 | g_loss: 2.0186
# Epoch [    7/   25] | d_loss: 0.9364 | g_loss: 1.1185
# Epoch [    7/   25] | d_loss: 0.4333 | g_loss: 3.1932
# Epoch [    7/   25] | d_loss: 0.6174 | g_loss: 2.5222
# Epoch [    7/   25] | d_loss: 0.4287 | g_loss: 3.7300
# Epoch [    8/   25] | d_loss: 0.5282 | g_loss: 3.3595
# Epoch [    8/   25] | d_loss: 0.4477 | g_loss: 2.8697
# Epoch [    8/   25] | d_loss: 0.6252 | g_loss: 2.3838
# Epoch [    8/   25] | d_loss: 0.5243 | g_loss: 3.2651
# Epoch [    8/   25] | d_loss: 0.5704 | g_loss: 3.0231
# Epoch [    8/   25] | d_loss: 0.4301 | g_loss: 3.6313
# Epoch [    8/   25] | d_loss: 0.5417 | g_loss: 3.0995
# Epoch [    8/   25] | d_loss: 0.5822 | g_loss: 2.1268
# Epoch [    8/   25] | d_loss: 0.4403 | g_loss: 2.9096
# Epoch [    8/   25] | d_loss: 0.4573 | g_loss: 3.8193
# Epoch [    9/   25] | d_loss: 0.4295 | g_loss: 3.2883
# Epoch [    9/   25] | d_loss: 0.5083 | g_loss: 3.3504
# Epoch [    9/   25] | d_loss: 0.4795 | g_loss: 4.4385
# Epoch [    9/   25] | d_loss: 1.8009 | g_loss: 1.1728
# Epoch [    9/   25] | d_loss: 0.4842 | g_loss: 3.5077
# Epoch [    9/   25] | d_loss: 0.4259 | g_loss: 3.1700
# Epoch [    9/   25] | d_loss: 0.3930 | g_loss: 4.6484
# Epoch [    9/   25] | d_loss: 1.2058 | g_loss: 2.6646
# Epoch [    9/   25] | d_loss: 0.5799 | g_loss: 2.1344
# Epoch [    9/   25] | d_loss: 0.4097 | g_loss: 3.0021
# Epoch [   10/   25] | d_loss: 0.3937 | g_loss: 3.3409
# Epoch [   10/   25] | d_loss: 0.4668 | g_loss: 2.3044
# Epoch [   10/   25] | d_loss: 0.5474 | g_loss: 3.4073
# Epoch [   10/   25] | d_loss: 0.5414 | g_loss: 2.6938
# Epoch [   10/   25] | d_loss: 0.4697 | g_loss: 3.7057
# Epoch [   10/   25] | d_loss: 0.3866 | g_loss: 3.5961
# Epoch [   10/   25] | d_loss: 0.4974 | g_loss: 2.5514
# Epoch [   10/   25] | d_loss: 0.3852 | g_loss: 3.5104
# Epoch [   10/   25] | d_loss: 0.5010 | g_loss: 3.3971
# Epoch [   10/   25] | d_loss: 0.4122 | g_loss: 3.1133
# Epoch [   11/   25] | d_loss: 0.4175 | g_loss: 3.9319
# Epoch [   11/   25] | d_loss: 0.5201 | g_loss: 2.3459
# Epoch [   11/   25] | d_loss: 0.4224 | g_loss: 3.8408
# Epoch [   11/   25] | d_loss: 0.5182 | g_loss: 3.7976
# Epoch [   11/   25] | d_loss: 0.3627 | g_loss: 4.7069
# Epoch [   11/   25] | d_loss: 0.4106 | g_loss: 3.4080
# Epoch [   11/   25] | d_loss: 0.4650 | g_loss: 3.4180
# Epoch [   11/   25] | d_loss: 0.3760 | g_loss: 3.3553
# Epoch [   11/   25] | d_loss: 0.4165 | g_loss: 4.8681
# Epoch [   11/   25] | d_loss: 0.6417 | g_loss: 1.1267
# Epoch [   12/   25] | d_loss: 0.4020 | g_loss: 3.1303
# Epoch [   12/   25] | d_loss: 0.4145 | g_loss: 2.9129
# Epoch [   12/   25] | d_loss: 0.4750 | g_loss: 3.1349
# Epoch [   12/   25] | d_loss: 0.4413 | g_loss: 4.2261
# Epoch [   12/   25] | d_loss: 0.4502 | g_loss: 4.3460
# Epoch [   12/   25] | d_loss: 0.4339 | g_loss: 3.2155
# Epoch [   12/   25] | d_loss: 0.3823 | g_loss: 5.9201
# Epoch [   12/   25] | d_loss: 0.3959 | g_loss: 3.2764
# Epoch [   12/   25] | d_loss: 0.5753 | g_loss: 2.0299
# Epoch [   12/   25] | d_loss: 0.4048 | g_loss: 3.6222
# Epoch [   13/   25] | d_loss: 0.3848 | g_loss: 4.1493
# Epoch [   13/   25] | d_loss: 0.4130 | g_loss: 4.0865
# Epoch [   13/   25] | d_loss: 0.3837 | g_loss: 3.3595
# Epoch [   13/   25] | d_loss: 0.3647 | g_loss: 4.5897
# Epoch [   13/   25] | d_loss: 0.4765 | g_loss: 2.9968
# Epoch [   13/   25] | d_loss: 0.4010 | g_loss: 3.9174
# Epoch [   13/   25] | d_loss: 0.3906 | g_loss: 3.3747
# Epoch [   13/   25] | d_loss: 0.4396 | g_loss: 3.3176
# Epoch [   13/   25] | d_loss: 0.5660 | g_loss: 2.5256
# Epoch [   13/   25] | d_loss: 0.5378 | g_loss: 3.8982
# Epoch [   14/   25] | d_loss: 0.3740 | g_loss: 3.9964
# Epoch [   14/   25] | d_loss: 0.4092 | g_loss: 4.0726
# Epoch [   14/   25] | d_loss: 0.3687 | g_loss: 4.0480
# Epoch [   14/   25] | d_loss: 0.4076 | g_loss: 3.6292
# Epoch [   14/   25] | d_loss: 0.3856 | g_loss: 4.0310
# Epoch [   14/   25] | d_loss: 0.3909 | g_loss: 3.9460
# Epoch [   14/   25] | d_loss: 0.4324 | g_loss: 4.1836
# Epoch [   14/   25] | d_loss: 0.4848 | g_loss: 3.2978
# Epoch [   14/   25] | d_loss: 0.3994 | g_loss: 4.3321
# Epoch [   14/   25] | d_loss: 0.3956 | g_loss: 4.5181
# Epoch [   15/   25] | d_loss: 0.4325 | g_loss: 3.5013
# Epoch [   15/   25] | d_loss: 0.4102 | g_loss: 3.1849
# Epoch [   15/   25] | d_loss: 0.4758 | g_loss: 2.9001
# Epoch [   15/   25] | d_loss: 0.3779 | g_loss: 5.0881
# Epoch [   15/   25] | d_loss: 0.4429 | g_loss: 3.9177
# Epoch [   15/   25] | d_loss: 0.3849 | g_loss: 4.7485
# Epoch [   15/   25] | d_loss: 0.5887 | g_loss: 2.4399
# Epoch [   15/   25] | d_loss: 0.3927 | g_loss: 2.5333
# Epoch [   15/   25] | d_loss: 0.3933 | g_loss: 4.4054
# Epoch [   15/   25] | d_loss: 0.4078 | g_loss: 3.9369
# Epoch [   16/   25] | d_loss: 0.4254 | g_loss: 3.9586
# Epoch [   16/   25] | d_loss: 0.3857 | g_loss: 4.6825
# Epoch [   16/   25] | d_loss: 0.3828 | g_loss: 4.6089
# Epoch [   16/   25] | d_loss: 0.3872 | g_loss: 3.3905
# Epoch [   16/   25] | d_loss: 0.3990 | g_loss: 3.3572
# Epoch [   16/   25] | d_loss: 0.3709 | g_loss: 4.7086
# Epoch [   16/   25] | d_loss: 0.3930 | g_loss: 3.5958
# Epoch [   16/   25] | d_loss: 0.6367 | g_loss: 2.7325
# Epoch [   16/   25] | d_loss: 0.4168 | g_loss: 3.6874
# Epoch [   16/   25] | d_loss: 0.4623 | g_loss: 3.2325
# Epoch [   17/   25] | d_loss: 0.4742 | g_loss: 1.6287
# Epoch [   17/   25] | d_loss: 0.3743 | g_loss: 4.0747
# Epoch [   17/   25] | d_loss: 0.4911 | g_loss: 2.4356
# Epoch [   17/   25] | d_loss: 0.4332 | g_loss: 3.5124
# Epoch [   17/   25] | d_loss: 0.4219 | g_loss: 3.2017
# Epoch [   17/   25] | d_loss: 0.3914 | g_loss: 2.8180
# Epoch [   17/   25] | d_loss: 0.3886 | g_loss: 4.4366
# Epoch [   17/   25] | d_loss: 0.3742 | g_loss: 4.5018
# Epoch [   17/   25] | d_loss: 0.3936 | g_loss: 3.9022
# Epoch [   17/   25] | d_loss: 0.3820 | g_loss: 5.5557
# Epoch [   18/   25] | d_loss: 0.5391 | g_loss: 2.9053
# Epoch [   18/   25] | d_loss: 0.4282 | g_loss: 4.1389
# Epoch [   18/   25] | d_loss: 0.4118 | g_loss: 3.5911
# Epoch [   18/   25] | d_loss: 0.3815 | g_loss: 4.8010
# Epoch [   18/   25] | d_loss: 0.4418 | g_loss: 3.6637
# Epoch [   18/   25] | d_loss: 0.3625 | g_loss: 4.4533
# Epoch [   18/   25] | d_loss: 0.3599 | g_loss: 3.8409
# Epoch [   18/   25] | d_loss: 0.8501 | g_loss: 4.2209
# Epoch [   18/   25] | d_loss: 0.3474 | g_loss: 5.1905
# Epoch [   18/   25] | d_loss: 0.3839 | g_loss: 4.3147
# Epoch [   19/   25] | d_loss: 0.4099 | g_loss: 4.2591
# Epoch [   19/   25] | d_loss: 0.3494 | g_loss: 4.6630
# Epoch [   19/   25] | d_loss: 0.3655 | g_loss: 4.6950
# Epoch [   19/   25] | d_loss: 0.3823 | g_loss: 4.7952
# Epoch [   19/   25] | d_loss: 0.3632 | g_loss: 4.0082
# Epoch [   19/   25] | d_loss: 0.3662 | g_loss: 4.0658
# Epoch [   19/   25] | d_loss: 0.4361 | g_loss: 2.9950
# Epoch [   19/   25] | d_loss: 0.3933 | g_loss: 4.3602
# Epoch [   19/   25] | d_loss: 0.5310 | g_loss: 5.6068
# Epoch [   19/   25] | d_loss: 0.3993 | g_loss: 4.8140
# Epoch [   20/   25] | d_loss: 0.3894 | g_loss: 5.2365
# Epoch [   20/   25] | d_loss: 0.3651 | g_loss: 4.8801
# Epoch [   20/   25] | d_loss: 0.3704 | g_loss: 3.3098
# Epoch [   20/   25] | d_loss: 0.4193 | g_loss: 2.4306
# Epoch [   20/   25] | d_loss: 0.7225 | g_loss: 1.1746
# Epoch [   20/   25] | d_loss: 0.3654 | g_loss: 4.3042
# Epoch [   20/   25] | d_loss: 0.4166 | g_loss: 3.9057
# Epoch [   20/   25] | d_loss: 0.3847 | g_loss: 4.2643
# Epoch [   20/   25] | d_loss: 0.7012 | g_loss: 3.8710
# Epoch [   20/   25] | d_loss: 0.3484 | g_loss: 6.1571
# Epoch [   21/   25] | d_loss: 0.4272 | g_loss: 3.9137
# Epoch [   21/   25] | d_loss: 0.3555 | g_loss: 5.9597
# Epoch [   21/   25] | d_loss: 0.3818 | g_loss: 5.1910
# Epoch [   21/   25] | d_loss: 0.3649 | g_loss: 3.1332
# Epoch [   21/   25] | d_loss: 0.3481 | g_loss: 4.8467
# Epoch [   21/   25] | d_loss: 0.3846 | g_loss: 5.0090
# Epoch [   21/   25] | d_loss: 0.3801 | g_loss: 4.3862
# Epoch [   21/   25] | d_loss: 0.4312 | g_loss: 5.9088
# Epoch [   21/   25] | d_loss: 0.3517 | g_loss: 4.0715
# Epoch [   21/   25] | d_loss: 0.4484 | g_loss: 4.1080
# Epoch [   22/   25] | d_loss: 0.3857 | g_loss: 5.1140
# Epoch [   22/   25] | d_loss: 0.3577 | g_loss: 6.1491
# Epoch [   22/   25] | d_loss: 0.3820 | g_loss: 4.9704
# Epoch [   22/   25] | d_loss: 0.3929 | g_loss: 4.2364
# Epoch [   22/   25] | d_loss: 0.3452 | g_loss: 5.1312
# Epoch [   22/   25] | d_loss: 0.4027 | g_loss: 2.7524
# Epoch [   22/   25] | d_loss: 0.3641 | g_loss: 5.3222
# Epoch [   22/   25] | d_loss: 0.3405 | g_loss: 4.6517
# Epoch [   22/   25] | d_loss: 0.4712 | g_loss: 3.6414
# Epoch [   22/   25] | d_loss: 0.5262 | g_loss: 3.2095
# Epoch [   23/   25] | d_loss: 0.3924 | g_loss: 5.4269
# Epoch [   23/   25] | d_loss: 0.4074 | g_loss: 5.4017
# Epoch [   23/   25] | d_loss: 0.3600 | g_loss: 6.2968
# Epoch [   23/   25] | d_loss: 0.3606 | g_loss: 5.9046
# Epoch [   23/   25] | d_loss: 0.4611 | g_loss: 2.3183
# Epoch [   23/   25] | d_loss: 0.3653 | g_loss: 4.8796
# Epoch [   23/   25] | d_loss: 0.3468 | g_loss: 5.2990
# Epoch [   23/   25] | d_loss: 0.3493 | g_loss: 4.6390
# Epoch [   23/   25] | d_loss: 0.3963 | g_loss: 5.3621
# Epoch [   23/   25] | d_loss: 0.3768 | g_loss: 4.7153
# Epoch [   24/   25] | d_loss: 0.3544 | g_loss: 5.7507
# Epoch [   24/   25] | d_loss: 0.4071 | g_loss: 3.6259
# Epoch [   24/   25] | d_loss: 0.3515 | g_loss: 6.4079
# Epoch [   24/   25] | d_loss: 0.4889 | g_loss: 4.5912
# Epoch [   24/   25] | d_loss: 0.3537 | g_loss: 4.5231
# Epoch [   24/   25] | d_loss: 0.3515 | g_loss: 6.1677
# Epoch [   24/   25] | d_loss: 0.3725 | g_loss: 6.9278
# Epoch [   24/   25] | d_loss: 0.3635 | g_loss: 6.2590
# Epoch [   24/   25] | d_loss: 0.3730 | g_loss: 3.8409
# Epoch [   24/   25] | d_loss: 0.3492 | g_loss: 5.9189
# Epoch [   25/   25] | d_loss: 0.4301 | g_loss: 3.6551
# Epoch [   25/   25] | d_loss: 0.4649 | g_loss: 3.8028
# Epoch [   25/   25] | d_loss: 0.3542 | g_loss: 4.2400
# Epoch [   25/   25] | d_loss: 0.3582 | g_loss: 4.5835
# Epoch [   25/   25] | d_loss: 0.4055 | g_loss: 3.4677
# Epoch [   25/   25] | d_loss: 0.3485 | g_loss: 4.7265
# Epoch [   25/   25] | d_loss: 0.4307 | g_loss: 5.0026
# Epoch [   25/   25] | d_loss: 0.3689 | g_loss: 4.8398
# Epoch [   25/   25] | d_loss: 0.3450 | g_loss: 6.9605
# Epoch [   25/   25] | d_loss: 0.3493 | g_loss: 5.3980

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Test with 20 epochs, dropout, beta1 = 0.2 and initial bias weights
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)
